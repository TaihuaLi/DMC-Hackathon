# %%
cd '/Users/TaihuaLi/Desktop/DMI/'
# Out:
# /Users/TaihuaLi/Desktop/DMI

# %%
import pandas as pd
import numpy as np
import CF as ur
import datetime
from sklearn import preprocessing

# %% [raw]
# -> use the following code to parse json and output to txt file
#
# with open('itamcojson2016.json', 'rb') as f:
#     data = f.readlines()
# data = map(lambda x: x.rstrip(), data)
# data_json_str = "[" + ','.join(data) + "]"
# d2016 = pd.read_json(data_json_str)
# d2016.to_csv("all 2016.txt", sep=";")

# %%
dat = pd.read_csv("all 2016.txt", sep=";", index_col=0)
# Out:
# /Users/TaihuaLi/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (2,3,4,5,6,7,11,15,16,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option("display.max_columns", dat.shape[1])

# %%
dat.head(5)
# Out:
#                                       _id alarm_code alarm_condition  \
# 0  {u'$oid': u'57622442ea3a8eb769cac0fc'}        NaN             NaN
# 1  {u'$oid': u'57622438ea3a8eb769cac0fb'}        NaN             NaN
# 2  {u'$oid': u'576223fbea3a8eb769cac0fa'}        NaN             NaN
# 3  {u'$oid': u'576223f1ea3a8eb769cac0f9'}        NaN             NaN
# 4  {u'$oid': u'576223ddea3a8eb769cac0f8'}        NaN             NaN
#
#   alarm_name alarm_nativeCode alarm_severity alarm_type  begin_dt_tm category  \
# 0        NaN              NaN            NaN        NaN   1466049599   Energy
# 1        NaN              NaN            NaN        NaN   1466049584   Energy
# 2        NaN              NaN            NaN        NaN   1466049528   Energy
# 3        NaN              NaN            NaN        NaN   1466049516   Energy
# 4        NaN              NaN            NaN        NaN   1466049499   Energy
#
#   component dataitemid     department  instance_id  machine_id mt_name  \
# ...

# %%
dat.describe(include="all")
# Out:
#                                            _id                  alarm_code  \
# count                                  8080474                      393466
# unique                                 8080474                           6
# top     {u'$oid': u'573474e2e6107f875a3cafe9'}  /NCU/CHANNEL#1/PARTPROGRAM
# freq                                         1                      326062
# mean                                       NaN                         NaN
# std                                        NaN                         NaN
# min                                        NaN                         NaN
# 25%                                        NaN                         NaN
# 50%                                        NaN                         NaN
# 75%                                        NaN                         NaN
# max                                        NaN                         NaN
#
# ...

# %%
to_export = e[e.machine_id == 155]

# %%
to_export.to_csv('machine155.csv', sep=",")

# %%
e = dat[dat.category == "Alarm"]

# %%
ME_df = pd.crosstab(e.machine_id, e.mt_value)

# %%
pd.set_option("display.max_columns", ME_df.shape[1])

# %%
ME_df.head(5)
# Out:
# mt_value    $67917  $67918 11.32332 INCH  $67918 11.4852 INCH  $67919  \
# machine_id
# 46               0                     0                    0       0
# 47              41                     0                    0       0
# 48               0                     0                    0       0
# 50               0                     0                    0       0
# 72               0                     0                    0       0
#
# mt_value    $67924 10.97627588  $86000  $86001  $86002  $86003  $86004  \
# machine_id
# 46                           0       0       0       0       0       0
# 47                           0   33754   25596    7611    7918     416
# 48                           0   26744   23643       0       0    2195
# 50                           0       0       0       0       0       0
# 72                           0       0       0       0       0       0
#
# mt_value    $86005  $86006  $86009  $86010  $86011  $86012  $86019  $86020  \
# machine_id
# ...

# %%
ME_df.columns.values
# Out:
# array(['$67917', '$67918 11.32332 INCH', '$67918 11.4852 INCH', '$67919',
#        '$67924 10.97627588', '$86000', '$86001', '$86002', '$86003',
#        '$86004', '$86005', '$86006', '$86009', '$86010', '$86011',
#        '$86012', '$86019', '$86020', '$86021', '$86022', '$86023',
#        '$86024', '$86029', '000',
#        'ACHTUNG: ES WERDEN BEREITS GESCHLIFFENE L?CKEN AUSGELASSEN! BITTE NILES-SERVICE INFORMIEREN',
#        'ACTIVE', 'ACTIVE LINE MODULE NOT ENABLED.', 'ALARM ON', 'ALARMS',
#        'ALARMS ACTIVE', 'ALARMS CLEARED',
#        'ATTENTION!WITH OF GRINDING WHEEL IS TO LARGE! COLLISION DANGER',
#        'AUTOMATIC MODE NOT SELECTED', 'AXIS A1 CONTOUR MONITORING',
#        'AXIS A1 DRIVE 1 TEST STOP IS RUNNING',
#        'AXIS A1 DRIVE 5 DIRECT FEEDBACK RECOGNIZED', 'AXIS A1 DRIVE FAULT',
#        'AXIS A1 SERVO_3.3:5_A1 (11):%NSI MOTION CU: STOP A INITIATED.',
#        'AXIS A1 SERVO_3.3:5_A1 (11):%NSI MOTION CU: STOP B INITIATED.',
# ...

# %%
indexes = list(ME_df.index)
test = indexes.index(133)
test
# Out:
# 6

# %%
pd.Da
# Out:
# []

# %%
if 46 in list(ME_df.index):
    print 5
else:
    print 'no'
# Out:
# 5

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
norm_dat = min_max_scaler.fit_transform(ME_df)

# %%
ME_df.shape
# Out:
# (24, 346)

# %%
ME_df.to_csv("alarm dat.csv", ",")

# %%
error_message = ME_df.columns.values

# %%
error_message.tofile("error message.txt", ";")

# %%
reload(ur)
# Out:
# <module 'CF' from 'CF.pyc'>

# %%
import time

# %%
start = time.time()
simMat = ur.getsim(np.array(norm_dat))
end = time.time()
# Out:
# /Users/TaihuaLi/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:2079: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)

# %%
print end-start
# Out:
# 5.86433315277

# %%
import csv

# %%
import json

# %%
with open('simMat.txt', 'w') as f:
    json.dump(simMat, f)

# %%
writer = csv.writer(open('simMat.txt', 'wb'))
for key, value in simMat.items():
    writer.writerow([key, value])

# %%
np.set_printoptions(precision=4)

# %%
ur.standEstTest(norm_dat, 0, simMat, 200)
# Out:
# 0

# %%
output = ur.recommend(norm_dat, 0, simMat)
output
# Out:
# [(0, 0.26666666666666666), (5, 0.26666666666666666), (6, 0.26666666666666666)]

# %%
output[1][0]
# Out:
# 1

# %%
sim = np.genfromtxt("simMat.txt", delimiter=)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-51822eb539be> in <module>()
# ----> 1 sim = np.genfromtxt("simMat.txt", delimiter='"')
#
# /Users/TaihuaLi/anaconda/lib/python2.7/site-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1764             # Raise an exception ?
#    1765             if invalid_raise:
# -> 1766                 raise ValueError(errmsg)
#    1767             # Issue a warning ?
#    1768             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 3 columns instead of 2)
#     Line #3 (got 3 columns instead of 2)
#     Line #4 (got 3 columns instead of 2)
# ...

# %%
sim
# Out:
# array([ nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
# ...

# %%
import json

# %%
new_dat = json.load(open("simMat.txt"))

# %%
new_dat['0'][1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-2236a55c6338> in <module>()
# ----> 1 new_dat['0'][1]
#
# KeyError: 1

# %%
str(1)
# Out:
# '1'
